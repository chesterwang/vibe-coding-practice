# %%
# %%bash
# pip3 install llama-index-embeddings-huggingface llama-index-llms-huggingface-api
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama-index-embeddings-huggingface in /home/chester/py_venv_ai/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: llama-index-llms-huggingface-api in /home/chester/py_venv_ai/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.34.3)
# Requirement already satisfied: llama-index-core<0.14,>=0.13.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (0.13.0)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (5.0.0)
# Requirement already satisfied: filelock in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.1.5)
# Requirement already satisfied: aiohttp in /home/chester/py_venv_ai/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.12.13)
# Requirement already satisfied: aiosqlite in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2.2.0)
# Requirement already satisfied: dataclasses-json in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.4.1)
# Requirement already satisfied: nltk>3.8.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2.2.6)
# Requirement already satisfied: pillow>=9.0.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (11.0.0)
# Requirement already satisfied: platformdirs in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2.11.7)
# Requirement already satisfied: setuptools>=80.9.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2.0.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.57.0)
# Requirement already satisfied: torch>=1.11.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.8.0+cpu)
# Requirement already satisfied: scikit-learn in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.7.0)
# Requirement already satisfied: scipy in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.20.1)
# Requirement already satisfied: griffe in /home/chester/py_venv_ai/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.9.0)
# Requirement already satisfied: jinja2 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.4.0)
# Requirement already satisfied: click in /home/chester/py_venv_ai/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (8.2.1)
# Requirement already satisfied: joblib in /home/chester/py_venv_ai/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.8.30)
# Requirement already satisfied: greenlet>=1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.2.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.26.1)
# Requirement already satisfied: anyio in /home/chester/py_venv_ai/lib/python3.12/site-packages (from httpx->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/chester/py_venv_ai/lib/python3.12/site-packages (from httpx->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chester/py_venv_ai/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index-embeddings-huggingface) (3.0.1)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Retrieve HF_TOKEN from the environment variables
hf_token = os.getenv("HUGGINGFACE_API_KEY")

os.environ['HTTP_PROXY'] = "http://127.0.0.1:7890"
os.environ['HTTPS_PROXY'] = "http://127.0.0.1:7890"
os.environ['NO_PROXY'] = "http://127.0.0.1:11434" #ollama的本地服务地址

llm = HuggingFaceInferenceAPI(
    model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
    temperature=0.7,
    max_tokens=100,
    token=hf_token,
    provider="auto"
)

response = llm.complete("Hello, how are you?")
print(response)
# I am good, how can I help you today?
# Out:
# True
# Hello! I'm just a computer program, so I don't have feelings, but thank you for asking. How can I assist you today?

# %%
from llama_index.core import SimpleDirectoryReader

reader = SimpleDirectoryReader(input_dir="./")
documents = reader.load_data()

# %%
print(documents[:3])
# Out:
# [Document(id_='6345a535-2f45-4e8c-a102-3a900483adc0', embedding=None, metadata={'file_path': '/home/chester/gitlab.chesterwang.com/chester-aigc-practice/2025-10-02-ai-agent-入门第一课/13 LlamaIndex框架.ipynb', 'file_name': '13 LlamaIndex框架.ipynb', 'file_size': 223707, 'creation_date': '2025-11-14', 'last_modified_date': '2025-11-14'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="\n\n\nget_ipython().run_cell_magic('bash', '', 'pip3 install llama-index-embeddings-huggingface llama-index-llms-huggingface-api\\n')\n\n\n# ", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='c54c24a0-f7ae-48a0-9a3c-c75c1b6f127a', embedding=None, metadata={'file_path': '/home/chester/gitlab.chesterwang.com/chester-aigc-practice/2025-10-02-ai-agent-入门第一课/13 LlamaIndex框架.ipynb', 'file_name': '13 LlamaIndex框架.ipynb', 'file_size': 223707, 'creation_date': '2025-11-14', 'last_modified_date': '2025-11-14'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n\n\nfrom llama_index.llms.huggingface_api import HuggingFaceInferenceAPI\nimport os\nfrom dotenv import load_dotenv\n\n# Load the .env file\nload_dotenv()\n\n# Retrieve HF_TOKEN from the environment variables\nhf_token = os.getenv("HUGGINGFACE_API_KEY")\n\nos.environ[\'HTTP_PROXY\'] = "http://127.0.0.1:7890"\nos.environ[\'HTTPS_PROXY\'] = "http://127.0.0.1:7890"\nos.environ[\'NO_PROXY\'] = "http://127.0.0.1:11434" #ollama的本地服务地址\n\nllm = HuggingFaceInferenceAPI(\n    model_name="Qwen/Qwen2.5-Coder-32B-Instruct",\n    temperature=0.7,\n    max_tokens=100,\n    token=hf_token,\n    provider="auto"\n)\n\nresponse = llm.complete("Hello, how are you?")\nprint(response)\n# I am good, how can I help you today?\n\n\n# ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='695f3309-405a-4638-bc1a-5feacfbc8c84', embedding=None, metadata={'file_path': '/home/chester/gitlab.chesterwang.com/chester-aigc-practice/2025-10-02-ai-agent-入门第一课/13 LlamaIndex框架.ipynb', 'file_name': '13 LlamaIndex框架.ipynb', 'file_size': 223707, 'creation_date': '2025-11-14', 'last_modified_date': '2025-11-14'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n\n\nfrom llama_index.core import SimpleDirectoryReader\n\nreader = SimpleDirectoryReader(input_dir="./")\ndocuments = reader.load_data()\n\n\n# ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
from llama_index.core import Document
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline

# create the pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(chunk_size=30,
                         chunk_overlap=0, 
                         paragraph_separator="\n"),
        HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5"),
    ]
)

nodes = await pipeline.arun(documents=[Document.example()])
nodes
# Out:
# 2025-11-14 09:40:17.673515: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-14 09:40:17.814792: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/chester/py_venv_ai/lib/python3.12/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# Metadata length (9) is close to chunk size (30). Resulting chunks are less than 50 tokens. Consider increasing the chunk size or decreasing the size of your metadata to avoid this.
# [TextNode(id_='dc700ad0-b0aa-4d59-bbfa-603ff0edef06', embedding=[-0.055600520223379135, 0.011091159656643867, 0.03558356687426567, -0.04144258052110672, 0.05192653834819794, -0.06519750505685806, 0.0023052787873893976, -0.0059931399300694466, 0.016246214509010315, -0.08449862897396088, -0.0028635100461542606, 0.02638329192996025, 0.02220352180302143, 0.015145150944590569, 0.03175486624240875, 0.022757485508918762, -0.0012810081243515015, 0.01564873568713665, -0.0016829823143780231, 0.04073594510555267, 0.06956089287996292, 0.004809209145605564, 0.03031214512884617, 0.00885833241045475, -0.0327761173248291, -0.012011103332042694, -0.05094118416309357, -0.01943393237888813, -0.08847642689943314, -0.1399543285369873, 0.006631513126194477, 0.035538654774427414, 0.028988275676965714, 0.034742243587970734, -0.002250063233077526, 0.005220198072493076, -0.011043024249374866, 0.010354076512157917, -0.013974783010780811, 0.037898581475019455, 0.023188922554254532, 0.0015241532819345593, 0.009562096558511257, 0.011220729909837246, -0.016646064817905426, -0.0806671679019928, 0.017247015610337257, -0.0011969937477260828, -0.07214587181806564, -0.06421125680208206, -0.005774158984422684, -0.033104848116636276, 0.03968527168035507, 0.019825341179966927, -0.033873528242111206, 0.05495062470436096, -0.004962177947163582, 0.02762913890182972, 0.009209743700921535, 0.006099975202232599, 0.05496753007173538, 0.03297000005841255, -0.1426120102405548, 0.0687967985

        HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5"),
    ],
    vector_store=vector_store,
)

# %%
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
index = VectorStoreIndex.from_vector_store(vector_store, embed_model=embed_model)

index.build_index_from_nodes(nodes)
# Out:
# IndexDict(index_id='553e8c23-a041-4f34-8e4f-d397524c4ca5', summary=None, nodes_dict={}, doc_id_dict={}, embeddings_dict={})

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI

llm = HuggingFaceInferenceAPI(model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
                              token=os.environ.get("HUGGINGFACE_API_KEY"),
                              provider="auto"
                              )
# 这里必须提供正确的provider参数，具体要查看hf官网右侧 是否有提供对应的provider 名字。这块还是没有搞明白，反正auto是可以的。
query_engine = index.as_query_engine(
    llm=llm,
    response_mode="tree_summarize",
)
query_engine.query("What is the meaning of life?")
# The meaning of life is 42
# Out:
# Response(response='The meaning of life is a profound question that has been explored by philosophers, scientists, and thinkers throughout history. It encompasses inquiries into the purpose and significance of existence. While the provided information discusses LLMs (Large Language Models) as tools for generating knowledge and reasoning, it does not address the philosophical or existential question of the meaning of life. This question remains open to interpretation and can vary greatly depending on individual beliefs, values, and experiences.', source_nodes=[NodeWithScore(node=TextNode(id_='969970f8-5f4b-498c-b193-06cb59639f4b', embedding=None, metadata={'filename': 'README.md', 'category': 'codebase'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='86887d64-9e53-4731-9a3e-c53105ab92c8', node_type='4', metadata={'filename': 'README.md', 'category': 'codebase'}, hash='8f24ce02310203160c5e18490ef2c8acba3077d47170f8d9ae1191e323687c3a'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2a5ba1f7-fbbf-45df-95a8-fef4f4ba2891', node_type='1', metadata={}, hash='c9d1076278a6f906f2a1751dbab7ad0b686b2f4c8b113ac2eec8faaf80bb2f16')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Context\nLLMs are a phenomenal piece of technology for knowledge generation and reasoning.', mimetype='text/plain', start_char_idx=1, end_char_idx=90, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.3535148694623115)], metadata={'969970f8-5f4b-498c-b193-06cb59639f4b': {'filename': 'README.md', 'category': 'codebase'}})

# %%
# ------这段代码失败了，搞不懂为什么，明明网络是通的。------
from llama_index.core.evaluation import FaithfulnessEvaluator

# query_engine = # from the previous section
# llm = # from the previous section

# query index
evaluator = FaithfulnessEvaluator(llm=llm)
response = query_engine.query(
    "What battles took place in New York City in the American Revolution?"
)
print(response)
eval_result = evaluator.evaluate_response(response=response)
eval_result.passing
# Out:
# During the American Revolution, several significant battles occurred in and around New York City. The most notable was the Battle of Long Island (also known as the Battle of Brooklyn) in August 1776, where British forces under General William Howe defeated the Continental Army led by General George Washington. Another major engagement was the Battle of Harlem Heights in September 1776, which resulted in a tactical victory for the Americans. Additionally, there were skirmishes and smaller battles throughout the occupation period from 1776 to 1783, including actions at Fort Washington and Fort Lee. These conflicts were crucial in shaping the strategic landscape of the revolution in the northeastern theater.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:1248, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1245 async with ceil_timeout(
#    1246     timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#    1247 ):
# -> 1248     sock = await aiohappyeyeballs.start_connection(
#    1249         addr_infos=addr_infos,
#    1250         local_addr_infos=self._local_addr_infos,
#    1251         happy_eyeballs_delay=self._happy_eyeballs_delay,
#    1252         interleave=self._interleave,
#    1253         loop=self._loop,
#    1254         socket_factory=self._socket_factory,
#    1255     )
#    1256     # Add ssl_shutdown_timeout for Python 3.11+ when SSL is used
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohappyeyeballs/impl.py:149, in start_connection(addr_infos, local_addr_infos, happy_eyeballs_delay, interleave, loop, socket_factory)
#     146         # We have a mix of OSError and RuntimeError
#     147         # so we have to pick which one to raise.
#     148         # and we raise OSError for compatibility
# --> 149         raise OSError(msg)
#     150 finally:
#
# OSError: Multiple exceptions: [Errno 110] Connect call failed ('159.106.121.75', 443), [Errno 101] Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# Cell In[16], line 12
#       8 response = query_engine.query(
#       9     "What battles took place in New York City in the American Revolution?"
#      10 )
#      11 print(response)
# ---> 12 eval_result = evaluator.evaluate_response(response=response)
#      13 eval_result.passing
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/evaluation/base.py:111, in BaseEvaluator.evaluate_response(self, query, response, **kwargs)
#     108     response_str = response.response
#     109     contexts = [node.get_content() for node in response.source_nodes]
# --> 111 return self.evaluate(
#     112     query=query, response=response_str, contexts=contexts, **kwargs
#     113 )
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/evaluation/base.py:67, in BaseEvaluator.evaluate(self, query, response, contexts, **kwargs)
#      53 def evaluate(
#      54     self,
#      55     query: Optional[str] = None,
#    (...)
#      58     **kwargs: Any,
#      59 ) -> EvaluationResult:
#      60     """
#      61     Run evaluation with query string, retrieved contexts,
#      62     and generated response string.
#    (...)
#      65     take in additional arguments.
#      66     """
# ---> 67     return asyncio_run(
#      68         self.aevaluate(
#      69             query=query,
#      70             response=response,
#      71             contexts=contexts,
#      72             **kwargs,
#      73         )
#      74     )
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/async_utils.py:49, in asyncio_run(coro)
#      47     with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
#      48         future = executor.submit(run_coro_in_thread)
# ---> 49         return future.result()
#      50 else:
#      51     # If we're here, there's an existing loop but it's not running
#      52     return loop.run_until_complete(coro)
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/async_utils.py:43, in asyncio_run.<locals>.run_coro_in_thread()
#      41 asyncio.set_event_loop(new_loop)
#      42 try:
# ---> 43     return new_loop.run_until_complete(coro)
#      44 finally:
#      45     new_loop.close()
#
# File /usr/lib/python3.12/asyncio/base_events.py:687, in BaseEventLoop.run_until_complete(self, future)
#     684 if not future.done():
#     685     raise RuntimeError('Event loop stopped before Future completed.')
# --> 687 return future.result()
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/evaluation/faithfulness.py:183, in FaithfulnessEvaluator.aevaluate(***failed resolving arguments***)
#     176 index = SummaryIndex.from_documents(docs)
#     178 query_engine = index.as_query_engine(
#     179     llm=self._llm,
#     180     text_qa_template=self._eval_template,
#     181     refine_template=self._refine_template,
#     182 )
# --> 183 response_obj = await query_engine.aquery(response)
#     185 raw_response_txt = str(response_obj)
#     187 if "yes" in raw_response_txt.lower():
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/base/base_query_engine.py:56, in BaseQueryEngine.aquery(self, str_or_query_bundle)
#      54     if isinstance(str_or_query_bundle, str):
#      55         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 56     query_result = await self._aquery(str_or_query_bundle)
#      57 dispatcher.event(
#      58     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      59 )
#      60 return query_result
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/query_engine/retriever_query_engine.py:210, in RetrieverQueryEngine._aquery(self, query_bundle)
#     205 with self.callback_manager.event(
#     206     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     207 ) as query_event:
#     208     nodes = await self.aretrieve(query_bundle)
# --> 210     response = await self._response_synthesizer.asynthesize(
#     211         query=query_bundle,
#     212         nodes=nodes,
#     213     )
#     215     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     217 return response
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/response_synthesizers/base.py:300, in BaseSynthesizer.asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     294     query = QueryBundle(query_str=query)
#     296 with self._callback_manager.event(
#     297     CBEventType.SYNTHESIZE,
#     298     payload={EventPayload.QUERY_STR: query.query_str},
#     299 ) as event:
# --> 300     response_str = await self.aget_response(
#     301         query_str=query.query_str,
#     302         text_chunks=[
#     303             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     304         ],
#     305         **response_kwargs,
#     306     )
#     308     additional_source_nodes = additional_source_nodes or []
#     309     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/response_synthesizers/compact_and_refine.py:23, in CompactAndRefine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      14 @dispatcher.span
#      15 async def aget_response(
#      16     self,
#    (...)
#      20     **response_kwargs: Any,
#      21 ) -> RESPONSE_TEXT_TYPE:
#      22     compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 23     return await super().aget_response(
#      24         query_str=query_str,
#      25         text_chunks=compact_texts,
#      26         prev_response=prev_response,
#      27         **response_kwargs,
#      28     )
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/response_synthesizers/refine.py:366, in Refine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     362 for text_chunk in text_chunks:
#     363     if prev_response is None:
#     364         # if this is the first chunk, and text chunk already
#     365         # is an answer, then return it
# --> 366         response = await self._agive_response_single(
#     367             query_str, text_chunk, **response_kwargs
#     368         )
#     369     else:
#     370         response = await self._arefine_response_single(
#     371             prev_response, query_str, text_chunk, **response_kwargs
#     372         )
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/response_synthesizers/refine.py:487, in Refine._agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     485 if response is None and not self._streaming:
#     486     try:
# --> 487         structured_response = await program.acall(
#     488             context_str=cur_text_chunk,
#     489             **response_kwargs,
#     490         )
#     491         structured_response = cast(
#     492             StructuredRefineResponse, structured_response
#     493         )
#     494         query_satisfied = structured_response.query_satisfied
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/response_synthesizers/refine.py:101, in DefaultRefineProgram.acall(self, *args, **kwds)
#      99         answer = answer.model_dump_json()
#     100 else:
# --> 101     answer = await self._llm.apredict(
#     102         self._prompt,
#     103         **kwds,
#     104     )
#     105 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/core/llms/llm.py:716, in LLM.apredict(self, prompt, **prompt_args)
#     714 if self.metadata.is_chat_model:
#     715     messages = self._get_messages(prompt, **prompt_args)
# --> 716     chat_response = await self.achat(messages)
#     717     output = chat_response.message.content or ""
#     718 else:
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:368, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     360 self.span_enter(
#     361     id_=id_,
#     362     bound_args=bound_args,
#    (...)
#     365     tags=tags,
#     366 )
#     367 try:
# --> 368     result = await func(*args, **kwargs)
#     369 except BaseException as e:
#     370     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/py_venv_ai/lib/python3.12/site-packages/llama_index/llms/huggingface_api/base.py:409, in HuggingFaceInferenceAPI.achat(self, messages, **kwargs)
#     406 if self.task == "conversational" or self.task is None:
#     407     model_kwargs = self._get_model_kwargs(**kwargs)
# --> 409     output: ChatCompletionOutput = await self._async_client.chat_completion(
#     410         messages=self._to_huggingface_messages(messages),
#     411         **model_kwargs,
#     412     )
#     414     content = output.choices[0].message.content or ""
#     415     tool_calls = output.choices[0].message.tool_calls or []
#
# File ~/py_venv_ai/lib/python3.12/site-packages/huggingface_hub/inference/_generated/_async_client.py:962, in AsyncInferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     934 parameters = {
#     935     "model": payload_model,
#     936     "frequency_penalty": frequency_penalty,
#    (...)
#     953     **(extra_body or {}),
#     954 }
#     955 request_parameters = provider_helper.prepare_request(
#     956     inputs=messages,
#     957     parameters=parameters,
#    (...)
#     960     api_key=self.token,
#     961 )
# --> 962 data = await self._inner_post(request_parameters, stream=stream)
#     964 if stream:
#     965     return _async_stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File ~/py_venv_ai/lib/python3.12/site-packages/huggingface_hub/inference/_generated/_async_client.py:265, in AsyncInferenceClient._inner_post(self, request_parameters, stream)
#     262 session = self._get_client_session(headers=request_parameters.headers)
#     264 try:
# --> 265     response = await session.post(
#     266         request_parameters.url, json=request_parameters.json, data=data_as_binary, proxy=self.proxies
#     267     )
#     268     response_error_payload = None
#     269     if response.status != 200:
#
# File ~/py_venv_ai/lib/python3.12/site-packages/huggingface_hub/inference/_generated/_async_client.py:3377, in AsyncInferenceClient._get_client_session.<locals>._request(method, url, **kwargs)
#    3376 async def _request(method, url, **kwargs):
# -> 3377     response = await session._wrapped_request(method, url, **kwargs)
#    3378     self._sessions[session].add(response)
#    3379     return response
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/client.py:770, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     767     handler = _connect_and_send_request
#     769 try:
# --> 770     resp = await handler(req)
#     771 # Client connector errors should not be retried
#     772 except (
#     773     ConnectionTimeoutError,
#     774     ClientConnectorError,
#     775     ClientConnectorCertificateError,
#     776     ClientConnectorSSLError,
#     777 ):
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/client.py:725, in ClientSession._request.<locals>._connect_and_send_request(req)
#     723 assert self._connector is not None
#     724 try:
# --> 725     conn = await self._connector.connect(
#     726         req, traces=traces, timeout=real_timeout
#     727     )
#     728 except asyncio.TimeoutError as exc:
#     729     raise ConnectionTimeoutError(
#     730         f"Connection timeout to host {req.url}"
#     731     ) from exc
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:622, in BaseConnector.connect(self, req, traces, timeout)
#     620     for trace in traces:
#     621         await trace.send_connection_create_start()
# --> 622 proto = await self._create_connection(req, traces, timeout)
#     623 if traces:
#     624     for trace in traces:
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:1189, in TCPConnector._create_connection(self, req, traces, timeout)
#    1187     _, proto = await self._create_proxy_connection(req, traces, timeout)
#    1188 else:
# -> 1189     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1191 return proto
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:1561, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1559 else:
#    1560     assert last_exc is not None
# -> 1561     raise last_exc
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:1530, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1525 server_hostname = (
#    1526     (req.server_hostname or host).rstrip(".") if sslcontext else None
#    1527 )
#    1529 try:
# -> 1530     transp, proto = await self._wrap_create_connection(
#    1531         self._factory,
#    1532         timeout=timeout,
#    1533         ssl=sslcontext,
#    1534         addr_infos=addr_infos,
#    1535         server_hostname=server_hostname,
#    1536         req=req,
#    1537         client_error=client_error,
#    1538     )
#    1539 except (ClientConnectorError, asyncio.TimeoutError) as exc:
#    1540     last_exc = exc
#
# File ~/py_venv_ai/lib/python3.12/site-packages/aiohttp/connector.py:1271, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1269 if exc.errno is None and isinstance(exc, asyncio.TimeoutError):
#    1270     raise
# -> 1271 raise client_error(req.connection_key, exc) from exc
#
# ClientConnectorError: Cannot connect to host router.huggingface.co:443 ssl:default [None]

# %%
from llama_index.core.tools import FunctionTool

def get_weather(location: str) -> str:
    """Useful for getting the weather for a given location."""
    print(f"Getting weather for {location}")
    return f"The weather in {location} is sunny"

tool = FunctionTool.from_defaults(
    get_weather,
    name="my_weather_tool",
    description="Useful for getting the weather for a given location.",
)
tool.call("New York")
# Out:
# Getting weather for New York
# ToolOutput(blocks=[TextBlock(block_type='text', text='The weather in New York is sunny')], tool_name='my_weather_tool', raw_input={'args': ('New York',), 'kwargs': {}}, raw_output='The weather in New York is sunny', is_error=False)

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.tools import QueryEngineTool
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.vector_stores.chroma import ChromaVectorStore

embed_model = HuggingFaceEmbedding("BAAI/bge-small-en-v1.5")

db = chromadb.PersistentClient(path="./alfred_chroma_db")
chroma_collection = db.get_or_create_collection("alfred")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

index = VectorStoreIndex.from_vector_store(vector_store, embed_model=embed_model)

llm = HuggingFaceInferenceAPI(model_name="Qwen/Qwen2.5-Coder-32B-Instruct")
query_engine = index.as_query_engine(llm=llm)
tool = QueryEngineTool.from_defaults(query_engine, name="some useful name", description="some useful description")

# %%
from llama_index.tools.google import GmailToolSpec

tool_spec = GmailToolSpec()
tool_spec_list = tool_spec.to_tool_list()

# %%
[(tool.metadata.name, tool.metadata.description) for tool in tool_spec_list]
# Out:
# [('load_data',
#   "load_data() -> List[llama_index.core.schema.Document]\nLoad emails from the user's account."),
#  ('search_messages',
#   "search_messages(query: str, max_results: Optional[int] = None)\nSearches email messages given a query string and the maximum number\n:param query: The user's query\n:param max_results: The maximum number of search results"),
#  ('create_draft',
#   'create_draft(to: Optional[List[str]] = None, subject: Optional[str] = None, message: Optional[str] = None) -> str\nCreate and insert a draft email.\n:param to: The email addresses to send the message to\n:param subject: The subject for the event\n:param message: The message for the event'),
#  ('update_draft',
#   'update_draft(to: Optional[List[str]] = None, subject: Optional[str] = None, message: Optional[str] = None, draft_id: str = None) -> str\nUpdate a draft email.\n:param to: The email addresses to send the message to\n:param subject: The subject for the event\n:param message: The message for the event\n:param draft_id: the id of the draft to be updated'),
#  ('get_draft',
#   'get_draft(draft_id: str = None) -> str\nGet a draft email.\n:param draft_id: the id of the draft to be updated'),
#  ('send_draft',
#   'send_draft(draft_id: str = None) -> str\nSends a draft email.\n:param draft_id: the id of the draft to be updated')]

# %%
## get_agent 错误的。
# 参考链接 [MCP ToolSpec](https://github.com/run-llama/llama_index/blob/13c1f8736388da188c27ec74365ff00b39b5b235/llama-index-integrations/tools/llama-index-tools-mcp/examples/mcp.ipynb#L75)
from llama_index.tools.mcp import BasicMCPClient, McpToolSpec
from llama_index.core.agent import get_agent,Context

# We consider there is a mcp server running on 127.0.0.1:8000, or you can use the mcp client to connect to your own mcp server.
mcp_client = BasicMCPClient("http://127.0.0.1:8000/sse")
mcp_tool = McpToolSpec(client=mcp_client)

# get the agent
agent = await get_agent(mcp_tool)

# create the agent context
agent_context = Context(agent)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 3
#       1 ## get_agent 错误的。
#       2 from llama_index.tools.mcp import BasicMCPClient, McpToolSpec
# ----> 3 from llama_index.core.agent import get_agent,Context
#       5 # We consider there is a mcp server running on 127.0.0.1:8000, or you can use the mcp client to connect to your own mcp server.
#       6 mcp_client = BasicMCPClient("http://127.0.0.1:8000/sse")
#
# ImportError: cannot import name 'get_agent' from 'llama_index.core.agent' (/home/chester/py_venv_ai/lib/python3.12/site-packages/llama_index/core/agent/__init__.py)

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
from llama_index.core.agent.workflow import AgentWorkflow
from llama_index.core.tools import FunctionTool

# define sample Tool -- type annotations, function names, and docstrings, are all included in parsed schemas!
def multiply(a: int, b: int) -> int:
    """Multiplies two integers and returns the resulting integer"""
    return a * b

# initialize llm
llm = HuggingFaceInferenceAPI(model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
                              token=os.environ.get("HUGGINGFACE_API_KEY"),
                              provider="auto"
)

# initialize agent
agent = AgentWorkflow.from_tools_or_functions(
    [FunctionTool.from_defaults(multiply)],
    llm=llm
)

# %%
# stateless
response = await agent.run("What is 2 times 2?")

# remembering state
from llama_index.core.workflow import Context

ctx = Context(agent)

response = await agent.run("My name is Bob.", ctx=ctx)
print(response)
response = await agent.run("What was my name again?", ctx=ctx)
print(response)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 # stateless
# ----> 2 response = await agent.run("What is 2 times 2?")
#       4 # remembering state
#       5 from llama_index.core.workflow import Context
#
# CancelledError:
